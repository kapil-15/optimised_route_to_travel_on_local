# %%
import camelot.io as camelot
# Out:
# e:\Project\optimised_route_to_travel_on_local\.venv\Lib\site-packages\pypdf\_crypt_providers\_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4

# %%
# Extract tables from PDF
tables = camelot.read_pdf(r"C:/Users/kapil/Downloads/central_line_.pdf", flavor='stream'
						  )

# Convert to DataFrame
# df = df(tables[0])  # First table
display(tables)

# display(tables[0].df)
# Out:
# <TableList n=3>

# %%
# Extract tables from PDF
tables_stream = camelot.read_pdf(r"C:/Users/kapil/Downloads/central_line_.pdf", flavor='stream', pages="all" )

# Convert to DataFrame
# df = df(tables[0])  # First table
display(tables_stream)

# display(tables[0].df)
# Out:
# <TableList n=22>

# %%
# Extract tables from PDF
tables_lattice = camelot.read_pdf(r"C:/Users/kapil/Downloads/central_line_.pdf", flavor="lattice", pages="all",  process_background = 1 
								  )

# Convert to DataFrame
# df = df(tables[0])  # First table
display(tables_lattice)

# display(tables[0].df)
# Out:
# <TableList n=18>

# %%
display(tables_stream[0].df)
# Out:
#                 0      1      2      3      4      5      6      7      8   \
# 0          STATION  96301  97601  96401  96101  97301  96001  96501  96103
# 1                     A 1    C 1    N 1    S 1    T 1  SKP 1  KAN 1   TS 1
# 2
# 3
# 4             CSMT  00:02  00:05  00:08  00:12  00:24
# 5           Masjid  00:05  00:08  00:11  00:15  00:27
# 6   Sandhurst Road  00:07  00:10  00:13  00:17  00:29
# 7          Byculla  00:10  00:13  00:16  00:20  00:32
# 8      Chinchpokli  00:12  00:15  00:18  00:22  00:34
# 9      Currey Road  00:14  00:17  00:20  00:24  00:36
# 10           Parel  00:17  00:20  00:23  00:27  00:39
# 11           Dadar  00:20  00:23  00:26  00:30  00:42
# 12         Matunga  00:23  00:26  00:29  00:33  00:45
# 13            Sion  00:26  00:29  00:32  00:36  00:48
# 14           Kurla  00:30  00:33  00:36  00:40  00:52
# 15      Vidyavihar  00:33         00:39  00:43  00:55
# 16       Ghatkopar  00:36         00:42  00:46  00:58
# ...

# %%
display(tables_lattice[0].df)
# Out:
#                                                    0
# 0                     CSMT- KALYAN - KHOPOLI- KASARA
# 1  STATION\n96301\n97601\n96401\n96101\n97301\n96...

# %%
tables_stream.export(r"./data/foo.csv", f='csv')
